# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
asthma_data_scaled = pd.read_pickle('asthma_data_scaled.pkl')

# %%
asthma_data_scaled
# Out:
#       patient_id  age  gender  ethnicity  education_level       bmi  smoking  \
# 0           5034   63       0          1                0 -1.582769        0
# 1           5035   26       1          2                2 -0.623300        0
# 2           5036   57       0          2                1 -1.229074        0
# 3           5037   40       1          2                1  1.565307        0
# 4           5038   61       0          0                3 -1.105686        0
# ...          ...  ...     ...        ...              ...       ...      ...
# 2387        7421   43       1          0                2  0.252042        0
# 2388        7422   18       1          0                1 -0.903322        0
# 2389        7423   54       0          3                2  1.365905        0
# 2390        7424   46       1          0                2 -0.527792        0
# 2391        7425   26       1          0                0  0.121962        1
#
# ...

# %%
#Create polynomial features or interaction terms
asthma_data_scaled['bmi_squared'] = asthma_data_scaled['bmi'] ** 2
asthma_data_scaled['age_bmi'] = asthma_data_scaled['age'] * asthma_data_scaled['bmi']
asthma_data_scaled['bmi_physical_activity'] = asthma_data_scaled['bmi'] * asthma_data_scaled['physical_activity']

# %%
asthma_data_scaled
# Out:
#       patient_id  age  gender  ethnicity  education_level       bmi  smoking  \
# 0           5034   63       0          1                0 -1.582769        0
# 1           5035   26       1          2                2 -0.623300        0
# 2           5036   57       0          2                1 -1.229074        0
# 3           5037   40       1          2                1  1.565307        0
# 4           5038   61       0          0                3 -1.105686        0
# ...          ...  ...     ...        ...              ...       ...      ...
# 2387        7421   43       1          0                2  0.252042        0
# 2388        7422   18       1          0                1 -0.903322        0
# 2389        7423   54       0          3                2  1.365905        0
# 2390        7424   46       1          0                2 -0.527792        0
# 2391        7425   26       1          0                0  0.121962        1
#
# ...
